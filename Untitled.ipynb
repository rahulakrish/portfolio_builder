# %%
#importing the requests library
import requests

# %% [markdown]
# Using [marketstack](https://marketstack.com/?utm_source=Geekflare&utm_medium=LeadsAcquisition&utm_content=Listing) to make API calls to retrieve end-of-day stock price of your preferred company.

# %% [markdown]
# API documentations can be found [here](https://marketstack.com/documentation). Code examples for different languages can be found [here](https://marketstack.com/documentation#php)

# %%
url = 'http://api.marketstack.com/v1/eod'
params = {
    'access_key' : '038908b69357069eadcfc963cbafe6ee',
    'symbols' : 'AAPL'    
}
resp = requests.get(url,params=params)

# %%
resp.status_code
# Out:
# 200

# %%
data = resp.json()

# %%
data
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 251},
#  'data': [{'open': 146.83,
#    'high': 147.2285,
#    'low': 145.01,
#    'close': 145.31,
#    'volume': 55478991.0,
#    'adj_high': 147.2285,
#    'adj_low': 145.01,
#    'adj_close': 145.31,
#    'adj_open': 146.83,
#    'adj_volume': 55478991.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-03-01T00:00:00+0000'},
#   {'open': 147.05,
#    'high': 149.075,
#    'low': 146.87,
#    'close': 147.41,
#    'volume': 50145937.0,
#    'adj_high': 149.08,
#    'adj_low': 146.83,
#    'adj_close': 147.41,
#    'adj_open': 147.05,
#    'adj_volume': 50546998.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-28T00:00:00+0000'},
#   {'open': 147.71,
#    'high': 149.17,
#    'low': 147.45,
#    'close': 147.92,
#    'volume': 44950000.0,
#    'adj_high': 149.17,
#    'adj_low': 147.45,
#    'adj_close': 147.92,
#    'adj_open': 147.71,
#    'adj_volume': 44998470.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-27T00:00:00+0000'},
#   {'open': 147.11,
#    'high': 147.19,
#    'low': 145.72,
#    'close': 146.71,
#    'volume': 55418200.0,
#    'adj_high': 147.19,
#    'adj_low': 145.7202,
#    'adj_close': 146.71,
#    'adj_open': 147.11,
#    'adj_volume': 55469606.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-24T00:00:00+0000'},
#   {'open': 150.09,
#    'high': 150.34,
#    'low': 147.24,
#    'close': 149.4,
#    'volume': 48349600.0,
#    'adj_high': 150.34,
#    'adj_low': 147.24,
#    'adj_close': 149.4,
#    'adj_open': 150.09,
#    'adj_volume': 48394249.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-23T00:00:00+0000'},
#   {'open': 148.87,
#    'high': 149.95,
#    'low': 147.16,
#    'close': 148.91,
#    'volume': 50939700.0,
#    'adj_high': 149.95,
#    'adj_low': 147.16,
#    'adj_close': 148.91,
#    'adj_open': 148.87,
#    'adj_volume': 51011305.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-22T00:00:00+0000'},
#   {'open': 150.2,
#    'high': 151.3,
#    'low': 148.41,
#    'close': 148.48,
#    'volume': 58772400.0,
#    'adj_high': 151.3,
#    'adj_low': 148.405,
#    'adj_close': 148.48,
#    'adj_open': 150.2,
#    'adj_volume': 58867230.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-21T00:00:00+0000'},
#   {'open': 152.35,
#    'high': 153.0,
#    'low': 150.85,
#    'close': 152.55,
#    'volume': 59144118.0,
#    'adj_high': 153.0,
#    'adj_low': 150.85,
#    'adj_close': 152.55,
#    'adj_open': 152.35,
#    'adj_volume': 59144118.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-17T00:00:00+0000'},
#   {'open': 153.51,
#    'high': 156.33,
#    'low': 153.35,
#    'close': 153.71,
#    'volume': 68031000.0,
#    'adj_high': 156.33,
#    'adj_low': 153.3475,
#    'adj_close': 153.71,
#    'adj_open': 153.51,
#    'adj_volume': 68167942.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-16T00:00:00+0000'},
#   {'open': 153.11,
#    'high': 155.5,
#    'low': 152.88,
#    'close': 155.33,
#    'volume': 65573800.0,
#    'adj_high': 155.5,
#    'adj_low': 152.88,
#    'adj_close': 155.33,
#    'adj_open': 153.11,
#    'adj_volume': 65669252.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-15T00:00:00+0000'},
#   {'open': 152.12,
#    'high': 153.77,
#    'low': 150.87,
#    'close': 153.2,
#    'volume': 61707573.0,
#    'adj_high': 153.77,
#    'adj_low': 150.86,
#    'adj_close': 153.2,
#    'adj_open': 152.12,
#    'adj_volume': 61707573.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-14T00:00:00+0000'},
#   {'open': 150.952,
#    'high': 154.26,
#    'low': 150.92,
#    'close': 153.85,
#    'volume': 62199013.0,
#    'adj_high': 154.26,
#    'adj_low': 150.92,
#    'adj_close': 153.85,
#    'adj_open': 150.952,
#    'adj_volume': 62199013.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-13T00:00:00+0000'},
#   {'open': 149.46,
#    'high': 151.34,
#    'low': 149.22,
#    'close': 151.01,
#    'volume': 57409100.0,
#    'adj_high': 151.3401,
#    'adj_low': 149.22,
#    'adj_close': 151.01,
#    'adj_open': 149.46,
#    'adj_volume': 57450708.0,
#    'split_factor': 1.0,
#    'dividend': 0.23,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-10T00:00:00+0000'},
#   {'open': 153.78,
#    'high': 154.33,
#    'low': 150.42,
#    'close': 150.87,
#    'volume': 55921800.0,
#    'adj_high': 154.33,
#    'adj_low': 150.42,
#    'adj_close': 150.64,
#    'adj_open': 153.775,
#    'adj_volume': 56007143.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-09T00:00:00+0000'},
#   {'open': 153.88,
#    'high': 154.58,
#    'low': 151.17,
#    'close': 151.92,
#    'volume': 64038100.0,
#    'adj_high': 154.58,
#    'adj_low': 151.168,
#    'adj_close': 151.92,
#    'adj_open': 153.88,
#    'adj_volume': 64120079.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-08T00:00:00+0000'},
#   {'open': 150.64,
#    'high': 155.23,
#    'low': 150.64,
#    'close': 154.65,
#    'volume': 83206400.0,
#    'adj_high': 155.23,
#    'adj_low': 150.64,
#    'adj_close': 154.65,
#    'adj_open': 150.64,
#    'adj_volume': 83322551.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-07T00:00:00+0000'},
#   {'open': 152.57,
#    'high': 153.1,
#    'low': 150.78,
#    'close': 151.73,
#    'volume': 69769900.0,
#    'adj_high': 153.1,
#    'adj_low': 150.78,
#    'adj_close': 151.73,
#    'adj_open': 152.575,
#    'adj_volume': 69858306.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-06T00:00:00+0000'},
#   {'open': 148.03,
#    'high': 157.38,
#    'low': 147.83,
#    'close': 154.5,
#    'volume': 154279900.0,
#    'adj_high': 157.38,
#    'adj_low': 147.83,
#    'adj_close': 154.5,
#    'adj_open': 148.03,
#    'adj_volume': 154357337.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-03T00:00:00+0000'},
#   {'open': 148.9,
#    'high': 151.18,
#    'low': 148.17,
#    'close': 150.82,
#    'volume': 116868600.0,
#    'adj_high': 151.18,
#    'adj_low': 148.17,
#    'adj_close': 150.82,
#    'adj_open': 148.9,
#    'adj_volume': 118338980.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-02T00:00:00+0000'},
#   {'open': 143.97,
#    'high': 146.61,
#    'low': 141.32,
#    'close': 145.43,
#    'volume': 77310900.0,
#    'adj_high': 146.61,
#    'adj_low': 141.32,
#    'adj_close': 145.43,
#    'adj_open': 143.97,
#    'adj_volume': 77663633.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-02-01T00:00:00+0000'},
#   {'open': 142.7,
#    'high': 144.34,
#    'low': 142.28,
#    'close': 144.29,
#    'volume': 60339047.0,
#    'adj_high': 144.34,
#    'adj_low': 142.28,
#    'adj_close': 144.29,
#    'adj_open': 142.7,
#    'adj_volume': 65874459.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-31T00:00:00+0000'},
#   {'open': 144.96,
#    'high': 145.55,
#    'low': 142.85,
#    'close': 143.0,
#    'volume': 63947600.0,
#    'adj_high': 145.55,
#    'adj_low': 142.85,
#    'adj_close': 143.0,
#    'adj_open': 144.955,
#    'adj_volume': 64015274.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-30T00:00:00+0000'},
#   {'open': 143.16,
#    'high': 147.23,
#    'low': 143.08,
#    'close': 145.93,
#    'volume': 70492800.0,
#    'adj_high': 147.23,
#    'adj_low': 143.08,
#    'adj_close': 145.93,
#    'adj_open': 143.155,
#    'adj_volume': 70555843.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-27T00:00:00+0000'},
#   {'open': 143.17,
#    'high': 144.25,
#    'low': 141.9,
#    'close': 143.96,
#    'volume': 54003800.0,
#    'adj_high': 144.25,
#    'adj_low': 141.9,
#    'adj_close': 143.96,
#    'adj_open': 143.17,
#    'adj_volume': 54105068.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-26T00:00:00+0000'},
#   {'open': 140.89,
#    'high': 142.43,
#    'low': 138.81,
#    'close': 141.86,
#    'volume': 65652500.0,
#    'adj_high': 142.43,
#    'adj_low': 138.81,
#    'adj_close': 141.86,
#    'adj_open': 140.89,
#    'adj_volume': 65799349.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-25T00:00:00+0000'},
#   {'open': 140.31,
#    'high': 143.16,
#    'low': 140.3,
#    'close': 142.53,
#    'volume': 66081800.0,
#    'adj_high': 143.16,
#    'adj_low': 140.3,
#    'adj_close': 142.53,
#    'adj_open': 140.305,
#    'adj_volume': 66435142.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-24T00:00:00+0000'},
#   {'open': 138.12,
#    'high': 143.32,
#    'low': 137.9,
#    'close': 141.11,
#    'volume': 81698400.0,
#    'adj_high': 143.315,
#    'adj_low': 137.9,
#    'adj_close': 141.11,
#    'adj_open': 138.12,
#    'adj_volume': 81760313.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-23T00:00:00+0000'},
#   {'open': 135.28,
#    'high': 138.02,
#    'low': 134.22,
#    'close': 137.87,
#    'volume': 79972200.0,
#    'adj_high': 138.02,
#    'adj_low': 134.22,
#    'adj_close': 137.87,
#    'adj_open': 135.28,
#    'adj_volume': 80223626.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-20T00:00:00+0000'},
#   {'open': 134.08,
#    'high': 136.25,
#    'low': 133.77,
#    'close': 135.27,
#    'volume': 58169700.0,
#    'adj_high': 136.25,
#    'adj_low': 133.77,
#    'adj_close': 135.27,
#    'adj_open': 134.08,
#    'adj_volume': 58280413.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-19T00:00:00+0000'},
#   {'open': 136.82,
#    'high': 138.61,
#    'low': 135.03,
#    'close': 135.21,
#    'volume': 69567000.0,
#    'adj_high': 138.61,
#    'adj_low': 135.03,
#    'adj_close': 135.21,
#    'adj_open': 136.815,
#    'adj_volume': 69672800.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-18T00:00:00+0000'},
#   {'open': 134.83,
#    'high': 137.29,
#    'low': 134.13,
#    'close': 135.94,
#    'volume': 63502900.0,
#    'adj_high': 137.29,
#    'adj_low': 134.13,
#    'adj_close': 135.94,
#    'adj_open': 134.83,
#    'adj_volume': 63646627.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-17T00:00:00+0000'},
#   {'open': 132.03,
#    'high': 134.92,
#    'low': 131.66,
#    'close': 134.76,
#    'volume': 57809719.0,
#    'adj_high': 134.92,
#    'adj_low': 131.66,
#    'adj_close': 134.76,
#    'adj_open': 132.03,
#    'adj_volume': 57809719.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-13T00:00:00+0000'},
#   {'open': 133.88,
#    'high': 134.26,
#    'low': 131.44,
#    'close': 133.41,
#    'volume': 71326100.0,
#    'adj_high': 134.26,
#    'adj_low': 131.44,
#    'adj_close': 133.41,
#    'adj_open': 133.88,
#    'adj_volume': 71379648.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-12T00:00:00+0000'},
#   {'open': 131.25,
#    'high': 133.51,
#    'low': 130.46,
#    'close': 133.49,
#    'volume': 69359700.0,
#    'adj_high': 133.51,
#    'adj_low': 130.46,
#    'adj_close': 133.49,
#    'adj_open': 131.25,
#    'adj_volume': 69458949.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-11T00:00:00+0000'},
#   {'open': 130.26,
#    'high': 131.26,
#    'low': 128.12,
#    'close': 130.73,
#    'volume': 63803400.0,
#    'adj_high': 131.2636,
#    'adj_low': 128.12,
#    'adj_close': 130.73,
#    'adj_open': 130.26,
#    'adj_volume': 63896155.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-10T00:00:00+0000'},
#   {'open': 130.47,
#    'high': 133.41,
#    'low': 129.89,
#    'close': 130.15,
#    'volume': 70675200.0,
#    'adj_high': 133.41,
#    'adj_low': 129.89,
#    'adj_close': 130.15,
#    'adj_open': 130.465,
#    'adj_volume': 70790813.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-09T00:00:00+0000'},
#   {'open': 126.01,
#    'high': 130.29,
#    'low': 124.89,
#    'close': 129.62,
#    'volume': 87686600.0,
#    'adj_high': 130.29,
#    'adj_low': 124.89,
#    'adj_close': 129.62,
#    'adj_open': 126.01,
#    'adj_volume': 87754715.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-06T00:00:00+0000'},
#   {'open': 127.13,
#    'high': 127.77,
#    'low': 124.76,
#    'close': 125.02,
#    'volume': 80829600.0,
#    'adj_high': 127.77,
#    'adj_low': 124.76,
#    'adj_close': 125.02,
#    'adj_open': 127.13,
#    'adj_volume': 80962708.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-05T00:00:00+0000'},
#   {'open': 126.89,
#    'high': 128.66,
#    'low': 125.08,
#    'close': 126.36,
#    'volume': 88886500.0,
#    'adj_high': 128.6557,
#    'adj_low': 125.08,
#    'adj_close': 126.36,
#    'adj_open': 126.89,
#    'adj_volume': 89113633.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-04T00:00:00+0000'},
#   {'open': 130.28,
#    'high': 130.9,
#    'low': 124.17,
#    'close': 125.07,
#    'volume': 111975500.0,
#    'adj_high': 130.9,
#    'adj_low': 124.17,
#    'adj_close': 125.07,
#    'adj_open': 130.28,
#    'adj_volume': 112117471.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2023-01-03T00:00:00+0000'},
#   {'open': 128.41,
#    'high': 129.95,
#    'low': 127.43,
#    'close': 129.93,
#    'volume': 77034209.0,
#    'adj_high': 129.95,
#    'adj_low': 127.43,
#    'adj_close': 129.93,
#    'adj_open': 128.41,
#    'adj_volume': 77034209.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-30T00:00:00+0000'},
#   {'open': 127.99,
#    'high': 130.48,
#    'low': 127.73,
#    'close': 129.61,
#    'volume': 75624700.0,
#    'adj_high': 130.4814,
#    'adj_low': 127.73,
#    'adj_close': 129.61,
#    'adj_open': 127.99,
#    'adj_volume': 75703710.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-29T00:00:00+0000'},
#   {'open': 129.67,
#    'high': 131.03,
#    'low': 125.87,
#    'close': 126.04,
#    'volume': 85323900.0,
#    'adj_high': 131.0275,
#    'adj_low': 125.87,
#    'adj_close': 126.04,
#    'adj_open': 129.67,
#    'adj_volume': 85438391.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-28T00:00:00+0000'},
#   {'open': 131.38,
#    'high': 131.41,
#    'low': 128.72,
#    'close': 130.03,
#    'volume': 68927300.0,
#    'adj_high': 131.41,
#    'adj_low': 128.72,
#    'adj_close': 130.03,
#    'adj_open': 131.38,
#    'adj_volume': 69007830.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-27T00:00:00+0000'},
#   {'open': 130.92,
#    'high': 132.415,
#    'low': 129.64,
#    'close': 131.86,
#    'volume': 63814893.0,
#    'adj_high': 132.415,
#    'adj_low': 129.64,
#    'adj_close': 131.86,
#    'adj_open': 130.92,
#    'adj_volume': 63814893.0,
#    'split_factor': 1.0,
#    'dividend': 0.17,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-23T00:00:00+0000'},
#   {'open': 134.352,
#    'high': 134.56,
#    'low': 130.3,
#    'close': 132.23,
#    'volume': 77852108.0,
#    'adj_high': 134.56,
#    'adj_low': 130.3,
#    'adj_close': 132.23,
#    'adj_open': 134.352,
#    'adj_volume': 77852108.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-22T00:00:00+0000'},
#   {'open': 132.98,
#    'high': 136.81,
#    'low': 132.75,
#    'close': 135.45,
#    'volume': 85927993.0,
#    'adj_high': 136.81,
#    'adj_low': 132.75,
#    'adj_close': 135.45,
#    'adj_open': 132.98,
#    'adj_volume': 85927993.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-21T00:00:00+0000'},
#   {'open': 131.39,
#    'high': 133.25,
#    'low': 129.89,
#    'close': 132.3,
#    'volume': 77432819.0,
#    'adj_high': 133.25,
#    'adj_low': 129.89,
#    'adj_close': 132.3,
#    'adj_open': 131.39,
#    'adj_volume': 77432819.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-20T00:00:00+0000'},
#   {'open': 135.11,
#    'high': 135.2,
#    'low': 131.32,
#    'close': 132.37,
#    'volume': 79592614.0,
#    'adj_high': 135.2,
#    'adj_low': 131.32,
#    'adj_close': 132.37,
#    'adj_open': 135.11,
#    'adj_volume': 79592614.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-19T00:00:00+0000'},
#   {'open': 136.69,
#    'high': 137.65,
#    'low': 133.73,
#    'close': 134.51,
#    'volume': 160080100.0,
#    'adj_high': 137.65,
#    'adj_low': 133.73,
#    'adj_close': 134.51,
#    'adj_open': 136.685,
#    'adj_volume': 160156900.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-16T00:00:00+0000'},
#   {'open': 141.11,
#    'high': 141.8,
#    'low': 136.025,
#    'close': 136.5,
#    'volume': 98931907.0,
#    'adj_high': 141.8,
#    'adj_low': 136.025,
#    'adj_close': 136.5,
#    'adj_open': 141.11,
#    'adj_volume': 98931907.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-15T00:00:00+0000'},
#   {'open': 145.35,
#    'high': 146.655,
#    'low': 141.16,
#    'close': 143.21,
#    'volume': 82291182.0,
#    'adj_high': 146.655,
#    'adj_low': 141.16,
#    'adj_close': 143.21,
#    'adj_open': 145.35,
#    'adj_volume': 82291182.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-14T00:00:00+0000'},
#   {'open': 149.5,
#    'high': 149.9692,
#    'low': 144.24,
#    'close': 145.47,
#    'volume': 93886161.0,
#    'adj_high': 149.9692,
#    'adj_low': 144.24,
#    'adj_close': 145.47,
#    'adj_open': 149.5,
#    'adj_volume': 93886161.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-13T00:00:00+0000'},
#   {'open': 142.7,
#    'high': 144.5,
#    'low': 141.06,
#    'close': 144.49,
#    'volume': 70462654.0,
#    'adj_high': 144.5,
#    'adj_low': 141.06,
#    'adj_close': 144.49,
#    'adj_open': 142.7,
#    'adj_volume': 70462654.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-12T00:00:00+0000'},
#   {'open': 142.34,
#    'high': 145.57,
#    'low': 140.9,
#    'close': 142.16,
#    'volume': 76069500.0,
#    'adj_high': 145.57,
#    'adj_low': 140.9,
#    'adj_close': 142.16,
#    'adj_open': 142.34,
#    'adj_volume': 76097011.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-09T00:00:00+0000'},
#   {'open': 142.36,
#    'high': 143.52,
#    'low': 141.1,
#    'close': 142.65,
#    'volume': 62128338.0,
#    'adj_high': 143.52,
#    'adj_low': 141.1,
#    'adj_close': 142.65,
#    'adj_open': 142.36,
#    'adj_volume': 62128338.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-08T00:00:00+0000'},
#   {'open': 142.19,
#    'high': 143.37,
#    'low': 140.0,
#    'close': 140.94,
#    'volume': 69721094.0,
#    'adj_high': 143.37,
#    'adj_low': 140.0,
#    'adj_close': 140.94,
#    'adj_open': 142.19,
#    'adj_volume': 69721094.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-07T00:00:00+0000'},
#   {'open': 147.075,
#    'high': 147.3,
#    'low': 141.92,
#    'close': 142.91,
#    'volume': 64727186.0,
#    'adj_high': 147.3,
#    'adj_low': 141.92,
#    'adj_close': 142.91,
#    'adj_open': 147.075,
#    'adj_volume': 64727186.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-06T00:00:00+0000'},
#   {'open': 147.77,
#    'high': 150.9199,
#    'low': 145.77,
#    'close': 146.63,
#    'volume': 68826442.0,
#    'adj_high': 150.9199,
#    'adj_low': 145.77,
#    'adj_close': 146.63,
#    'adj_open': 147.77,
#    'adj_volume': 68826442.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-05T00:00:00+0000'},
#   {'open': 145.96,
#    'high': 148.0,
#    'low': 145.65,
#    'close': 147.81,
#    'volume': 65421400.0,
#    'adj_high': 148.0,
#    'adj_low': 145.65,
#    'adj_close': 147.81,
#    'adj_open': 145.96,
#    'adj_volume': 65447446.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-02T00:00:00+0000'},
#   {'open': 148.21,
#    'high': 149.13,
#    'low': 146.61,
#    'close': 148.31,
#    'volume': 71250414.0,
#    'adj_high': 149.13,
#    'adj_low': 146.61,
#    'adj_close': 148.31,
#    'adj_open': 148.21,
#    'adj_volume': 71250416.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-12-01T00:00:00+0000'},
#   {'open': 141.395,
#    'high': 148.72,
#    'low': 140.55,
#    'close': 148.03,
#    'volume': 111380898.0,
#    'adj_high': 148.72,
#    'adj_low': 140.55,
#    'adj_close': 148.03,
#    'adj_open': 141.395,
#    'adj_volume': 111380880.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-30T00:00:00+0000'},
#   {'open': 144.29,
#    'high': 144.81,
#    'low': 140.355,
#    'close': 141.17,
#    'volume': 83763797.0,
#    'adj_high': 144.81,
#    'adj_low': 140.355,
#    'adj_close': 141.17,
#    'adj_open': 144.29,
#    'adj_volume': 83763803.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-29T00:00:00+0000'},
#   {'open': 145.14,
#    'high': 146.64,
#    'low': 143.38,
#    'close': 144.22,
#    'volume': 69346523.0,
#    'adj_high': 146.64,
#    'adj_low': 143.38,
#    'adj_close': 144.22,
#    'adj_open': 145.14,
#    'adj_volume': 69346522.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-28T00:00:00+0000'},
#   {'open': 148.31,
#    'high': 148.88,
#    'low': 147.12,
#    'close': 148.11,
#    'volume': 35195900.0,
#    'adj_high': 148.88,
#    'adj_low': 147.12,
#    'adj_close': 148.11,
#    'adj_open': 148.305,
#    'adj_volume': 35195860.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-25T00:00:00+0000'},
#   {'open': 149.45,
#    'high': 151.83,
#    'low': 149.34,
#    'close': 151.07,
#    'volume': 58301395.0,
#    'adj_high': 151.83,
#    'adj_low': 149.34,
#    'adj_close': 151.07,
#    'adj_open': 149.45,
#    'adj_volume': 58301395.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-23T00:00:00+0000'},
#   {'open': 148.13,
#    'high': 150.42,
#    'low': 146.925,
#    'close': 150.18,
#    'volume': 51804132.0,
#    'adj_high': 150.42,
#    'adj_low': 146.925,
#    'adj_close': 150.18,
#    'adj_open': 148.13,
#    'adj_volume': 51804132.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-22T00:00:00+0000'},
#   {'open': 150.16,
#    'high': 150.37,
#    'low': 147.715,
#    'close': 148.01,
#    'volume': 58724070.0,
#    'adj_high': 150.37,
#    'adj_low': 147.715,
#    'adj_close': 148.01,
#    'adj_open': 150.16,
#    'adj_volume': 58724070.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-21T00:00:00+0000'},
#   {'open': 152.31,
#    'high': 152.7,
#    'low': 149.97,
#    'close': 151.29,
#    'volume': 74794600.0,
#    'adj_high': 152.7,
#    'adj_low': 149.97,
#    'adj_close': 151.29,
#    'adj_open': 152.305,
#    'adj_volume': 74829573.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-18T00:00:00+0000'},
#   {'open': 146.43,
#    'high': 151.48,
#    'low': 146.15,
#    'close': 150.72,
#    'volume': 80389400.0,
#    'adj_high': 151.48,
#    'adj_low': 146.15,
#    'adj_close': 150.72,
#    'adj_open': 146.43,
#    'adj_volume': 80389400.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-17T00:00:00+0000'},
#   {'open': 149.13,
#    'high': 149.87,
#    'low': 147.29,
#    'close': 148.79,
#    'volume': 64218273.0,
#    'adj_high': 149.87,
#    'adj_low': 147.29,
#    'adj_close': 148.79,
#    'adj_open': 149.13,
#    'adj_volume': 64218266.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-16T00:00:00+0000'},
#   {'open': 152.215,
#    'high': 153.59,
#    'low': 148.5613,
#    'close': 150.04,
#    'volume': 89868328.0,
#    'adj_high': 153.59,
#    'adj_low': 148.5613,
#    'adj_close': 150.04,
#    'adj_open': 152.215,
#    'adj_volume': 89868332.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-15T00:00:00+0000'},
#   {'open': 148.97,
#    'high': 150.28,
#    'low': 147.43,
#    'close': 148.28,
#    'volume': 73374114.0,
#    'adj_high': 150.28,
#    'adj_low': 147.43,
#    'adj_close': 148.28,
#    'adj_open': 148.97,
#    'adj_volume': 73374114.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-14T00:00:00+0000'},
#   {'open': 145.82,
#    'high': 150.01,
#    'low': 144.37,
#    'close': 149.7,
#    'volume': 93903800.0,
#    'adj_high': 150.01,
#    'adj_low': 144.37,
#    'adj_close': 149.7,
#    'adj_open': 145.82,
#    'adj_volume': 93979665.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-11T00:00:00+0000'},
#   {'open': 141.24,
#    'high': 146.87,
#    'low': 139.5,
#    'close': 146.87,
#    'volume': 118854028.0,
#    'adj_high': 146.87,
#    'adj_low': 139.5,
#    'adj_close': 146.87,
#    'adj_open': 141.24,
#    'adj_volume': 118854028.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-10T00:00:00+0000'},
#   {'open': 138.5,
#    'high': 138.55,
#    'low': 134.5933,
#    'close': 134.87,
#    'volume': 74917794.0,
#    'adj_high': 138.55,
#    'adj_low': 134.5933,
#    'adj_close': 134.87,
#    'adj_open': 138.5,
#    'adj_volume': 74917794.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-09T00:00:00+0000'},
#   {'open': 140.41,
#    'high': 141.43,
#    'low': 137.49,
#    'close': 139.5,
#    'volume': 89908477.0,
#    'adj_high': 141.43,
#    'adj_low': 137.49,
#    'adj_close': 139.5,
#    'adj_open': 140.41,
#    'adj_volume': 89908477.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-08T00:00:00+0000'},
#   {'open': 137.11,
#    'high': 139.145,
#    'low': 135.671,
#    'close': 138.92,
#    'volume': 83374628.0,
#    'adj_high': 139.145,
#    'adj_low': 135.671,
#    'adj_close': 138.92,
#    'adj_open': 137.11,
#    'adj_volume': 83374628.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-07T00:00:00+0000'},
#   {'open': 142.09,
#    'high': 142.67,
#    'low': 134.38,
#    'close': 138.38,
#    'volume': 140716700.0,
#    'adj_high': 142.67,
#    'adj_low': 134.38,
#    'adj_close': 138.38,
#    'adj_open': 142.09,
#    'adj_volume': 140814796.0,
#    'split_factor': 1.0,
#    'dividend': 0.23,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-04T00:00:00+0000'},
#   {'open': 142.06,
#    'high': 142.8,
#    'low': 138.75,
#    'close': 138.88,
#    'volume': 97572100.0,
#    'adj_high': 142.8,
#    'adj_low': 138.75,
#    'adj_close': 138.65,
#    'adj_open': 142.06,
#    'adj_volume': 97918516.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-03T00:00:00+0000'},
#   {'open': 148.95,
#    'high': 152.17,
#    'low': 145.0,
#    'close': 145.03,
#    'volume': 93436100.0,
#    'adj_high': 152.17,
#    'adj_low': 145.0,
#    'adj_close': 145.03,
#    'adj_open': 148.945,
#    'adj_volume': 93604623.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-02T00:00:00+0000'},
#   {'open': 155.08,
#    'high': 155.45,
#    'low': 149.13,
#    'close': 150.65,
#    'volume': 80321400.0,
#    'adj_high': 155.45,
#    'adj_low': 149.13,
#    'adj_close': 150.65,
#    'adj_open': 155.08,
#    'adj_volume': 80379345.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-11-01T00:00:00+0000'},
#   {'open': 153.16,
#    'high': 154.24,
#    'low': 151.92,
#    'close': 153.34,
#    'volume': 97848900.0,
#    'adj_high': 154.24,
#    'adj_low': 151.92,
#    'adj_close': 153.34,
#    'adj_open': 153.155,
#    'adj_volume': 97943171.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-31T00:00:00+0000'},
#   {'open': 148.2,
#    'high': 157.5,
#    'low': 147.82,
#    'close': 155.74,
#    'volume': 164659100.0,
#    'adj_high': 157.5,
#    'adj_low': 147.82,
#    'adj_close': 155.74,
#    'adj_open': 148.2,
#    'adj_volume': 164762371.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-28T00:00:00+0000'},
#   {'open': 148.07,
#    'high': 149.05,
#    'low': 144.13,
#    'close': 144.8,
#    'volume': 108284100.0,
#    'adj_high': 149.046,
#    'adj_low': 144.13,
#    'adj_close': 144.8,
#    'adj_open': 148.07,
#    'adj_volume': 109180150.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-27T00:00:00+0000'},
#   {'open': 150.96,
#    'high': 151.99,
#    'low': 148.04,
#    'close': 149.35,
#    'volume': 88194300.0,
#    'adj_high': 151.99,
#    'adj_low': 148.04,
#    'adj_close': 149.35,
#    'adj_open': 150.96,
#    'adj_volume': 88436172.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-26T00:00:00+0000'},
#   {'open': 150.09,
#    'high': 152.49,
#    'low': 149.36,
#    'close': 152.34,
#    'volume': 74373600.0,
#    'adj_high': 152.49,
#    'adj_low': 149.36,
#    'adj_close': 152.34,
#    'adj_open': 150.09,
#    'adj_volume': 74732290.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-25T00:00:00+0000'},
#   {'open': 147.19,
#    'high': 150.23,
#    'low': 146.0,
#    'close': 149.45,
#    'volume': 75904300.0,
#    'adj_high': 150.23,
#    'adj_low': 146.0,
#    'adj_close': 149.45,
#    'adj_open': 147.185,
#    'adj_volume': 75981918.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-24T00:00:00+0000'},
#   {'open': 142.87,
#    'high': 147.85,
#    'low': 142.65,
#    'close': 147.27,
#    'volume': 86464700.0,
#    'adj_high': 147.8479,
#    'adj_low': 142.649,
#    'adj_close': 147.27,
#    'adj_open': 142.87,
#    'adj_volume': 86548609.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-21T00:00:00+0000'},
#   {'open': 143.02,
#    'high': 145.89,
#    'low': 142.65,
#    'close': 143.39,
#    'volume': 64406600.0,
#    'adj_high': 145.89,
#    'adj_low': 142.65,
#    'adj_close': 143.39,
#    'adj_open': 143.02,
#    'adj_volume': 64521989.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-20T00:00:00+0000'},
#   {'open': 141.69,
#    'high': 144.95,
#    'low': 141.5,
#    'close': 143.86,
#    'volume': 61655900.0,
#    'adj_high': 144.9492,
#    'adj_low': 141.5,
#    'adj_close': 143.86,
#    'adj_open': 141.69,
#    'adj_volume': 61758340.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-19T00:00:00+0000'},
#   {'open': 145.49,
#    'high': 146.7,
#    'low': 140.61,
#    'close': 143.75,
#    'volume': 98961900.0,
#    'adj_high': 146.7,
#    'adj_low': 140.61,
#    'adj_close': 143.75,
#    'adj_open': 145.49,
#    'adj_volume': 99136610.0,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-18T00:00:00+0000'},
#   {'open': 141.07,
#    'high': 142.9,
#    'low': 140.27,
#    'close': 142.41,
#    'volume': 85073900.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 142.41,
#    'adj_open': None,
#    'adj_volume': None,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-17T00:00:00+0000'},
#   {'open': 144.31,
#    'high': 144.52,
#    'low': 138.19,
#    'close': 138.38,
#    'volume': 88512300.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 138.38,
#    'adj_open': None,
#    'adj_volume': None,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-14T00:00:00+0000'},
#   {'open': 134.99,
#    'high': 143.59,
#    'low': 134.37,
#    'close': 142.99,
#    'volume': 113120700.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 142.99,
#    'adj_open': None,
#    'adj_volume': None,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-13T00:00:00+0000'},
#   {'open': 139.13,
#    'high': 140.36,
#    'low': 138.16,
#    'close': 138.34,
#    'volume': 70374100.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 138.34,
#    'adj_open': None,
#    'adj_volume': None,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-12T00:00:00+0000'},
#   {'open': 139.9,
#    'high': 141.35,
#    'low': 138.22,
#    'close': 138.98,
#    'volume': 76969200.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 138.98,
#    'adj_open': None,
#    'adj_volume': None,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-11T00:00:00+0000'},
#   {'open': 140.42,
#    'high': 141.89,
#    'low': 138.57,
#    'close': 140.42,
#    'volume': 74827900.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 140.42,
#    'adj_open': None,
#    'adj_volume': None,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-10T00:00:00+0000'},
#   {'open': 142.54,
#    'high': 143.1,
#    'low': 139.45,
#    'close': 140.09,
#    'volume': 85859100.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 140.09,
#    'adj_open': None,
#    'adj_volume': None,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-07T00:00:00+0000'},
#   {'open': 145.81,
#    'high': 147.54,
#    'low': 145.22,
#    'close': 145.43,
#    'volume': 68285900.0,
#    'adj_high': None,
#    'adj_low': None,
#    'adj_close': 145.43,
#    'adj_open': None,
#    'adj_volume': None,
#    'split_factor': 1.0,
#    'dividend': 0.0,
#    'symbol': 'AAPL',
#    'exchange': 'XNAS',
#    'date': '2022-10-06T00:00:00+0000'}]}

# %%
data['data'][0]['date']
# Out:
# '2023-03-01T00:00:00+0000'

# %%
data['data'][99]['date']
# Out:
# '2022-10-06T00:00:00+0000'
